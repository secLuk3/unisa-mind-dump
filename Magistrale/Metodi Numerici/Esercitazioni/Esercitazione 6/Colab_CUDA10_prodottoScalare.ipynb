# %% [markdown]
# # CUDA 10.2.89

# %%
# !wget wget http://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run -O cuda_10.2.deb
# Out:
# --2022-11-24 15:49:53--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2022-11-24 15:49:53--  http://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run [following]
# --2022-11-24 15:49:53--  https://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [1,038 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# ...

# %%
# !apt-get install cuda-10.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'cuda-10-2' for regex 'cuda-10.2'
# Note, selecting 'libcuda-10.2-1' for regex 'cuda-10.2'
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   cuda-command-line-tools-10-2 cuda-compiler-10-2 cuda-cudart-10-2
#   cuda-cudart-dev-10-2 cuda-cufft-10-2 cuda-cufft-dev-10-2 cuda-cuobjdump-10-2
#   cuda-cupti-10-2 cuda-cupti-dev-10-2 cuda-curand-10-2 cuda-curand-dev-10-2
#   cuda-cusolver-10-2 cuda-cusolver-dev-10-2 cuda-cusparse-10-2
#   cuda-cusparse-dev-10-2 cuda-demo-suite-10-2 cuda-documentation-10-2
#   cuda-driver-dev-10-2 cuda-gdb-10-2 cuda-libraries-10-2
#   cuda-libraries-dev-10-2 cuda-license-10-2 cuda-memcheck-10-2
#   cuda-misc-headers-10-2 cuda-npp-10-2 cuda-npp-dev-10-2 cuda-nsight-10-2
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Wed_Oct_23_19:24:38_PDT_2019
# Cuda compilation tools, release 10.2, V10.2.89

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd '/content/gdrive/My Drive/Colab Notebooks/Esercitazioni/Esercitazione 6'
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Esercitazioni/Esercitazione 6

# %%
! ls
# Out:
#  Colab_CUDA10_prodottoScalare.ipynb   prodottoScalareS1.cu
# 'Esercitazione 6.pdf'		      prodottoScalareS2.cu
#  prodottoScalareS1

# %%
! nvcc prodottoScalareS1.cu -o prodottoScalareS1

# %%
! ./prodottoScalareS1
# Out:
# ***	 PRODOTTO DI DUE VETTORI 	***
# Inserisci il numero degli elementi dei vettori
# 131072
# Grid dim x: 2048tempo GPU = 0.566304
# tempo CPU = 0.975584
#
# ---> Il prodotto scalare calcolato dalla CPU è: -681.00
#
# ---> Il prodotto scalare calcolato dalla GPU è: -681.00

# %%
! nvcc prodottoScalareS2.cu -o prodottoScalareS2

# %%
! ./prodottoScalareS2
# Out:
# ***	 Prodotto scalare vettori - 2 strategia 	***
# Inserisci il numero degli elementi dei vettori
# 131072
# tempo GPU = 0.045792
# tempo CPU = 0.966752
#
# ---> Il prodotto scalare calcolato dalla CPU è: -118.00
#
# ---> Il prodotto scalare calcolato dalla GPU è: -118.00

# %%
! nvcc prodottoScalareS3.cu -o prodottoScalareS3

# %%
! ./prodottoScalareS3
# Out:
# ***	 Prodotto scalare vettori - 3 strategia 	***
# Inserisci il numero degli elementi dei vettori
# 131072
# tempo GPU = 0.059616
# tempo CPU = 1.004992
#
# ---> Il prodotto scalare calcolato dalla CPU è: 1101.00
#
# ---> Il prodotto scalare calcolato dalla GPU è: 1101.00

# %%
# !nvidia-smi
# Out:
# Wed Nov 30 16:35:55 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc -Xptxas -v prodottoScalare.cu
# Out:
# ptxas info    : 0 bytes gmem
# ptxas info    : Compiling entry function '_Z18prodottoScalareGPUPfS_S_i' for 'sm_52'
# ptxas info    : Function properties for _Z18prodottoScalareGPUPfS_S_i
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 8 registers, 348 bytes cmem[0]

# %%
# !nvcc -Xptxas -v prodottoScalareS1.cu
# Out:
# ptxas info    : 0 bytes gmem
# ptxas info    : Compiling entry function '_Z18prodottoScalareGPUPfS_S_i' for 'sm_52'
# ptxas info    : Function properties for _Z18prodottoScalareGPUPfS_S_i
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 8 registers, 348 bytes cmem[0]

# %%
# !nvcc -Xptxas -v prodottoScalareS2.cu
# Out:
# ptxas info    : 0 bytes gmem
# ptxas info    : Compiling entry function '_Z18prodottoScalareGPUPfS_S_i' for 'sm_52'
# ptxas info    : Function properties for _Z18prodottoScalareGPUPfS_S_i
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 30 registers, 348 bytes cmem[0]

# %%
# !nvcc -Xptxas -v prodottoScalareS3.cu
# Out:
# ptxas info    : 0 bytes gmem
# ptxas info    : Compiling entry function '_Z18prodottoScalareGPUPfS_S_i' for 'sm_52'
# ptxas info    : Function properties for _Z18prodottoScalareGPUPfS_S_i
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 10 registers, 348 bytes cmem[0]

# %%
# !nvprof ./prodottoScalareS1
# Out:
# ***	 PRODOTTO DI DUE VETTORI 	***
# Inserisci il numero degli elementi dei vettori
# 8192
# ==556== NVPROF is profiling process 556, command: ./prodottoScalareS1
# Grid dim x: 128tempo GPU = 0.090944
# tempo CPU = 0.086592
#
# ---> Il prodotto scalare calcolato dalla CPU è: -78.00
#
# ---> Il prodotto scalare calcolato dalla GPU è: -78.00==556== Profiling application: ./prodottoScalareS1
# ==556== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   41.42%  10.431us         2  5.2150us  5.1840us  5.2470us  [CUDA memcpy HtoD]
#                    20.33%  5.1200us         1  5.1200us  5.1200us  5.1200us  prodottoScalareGPU(float*, float*, float*, int)
#                    20.33%  5.1200us         1  5.1200us  5.1200us  5.1200us  [CUDA memset]
#                    17.92%  4.5120us         1  4.5120us  4.5120us  4.5120us  [CUDA memcpy DtoH]
# ...
