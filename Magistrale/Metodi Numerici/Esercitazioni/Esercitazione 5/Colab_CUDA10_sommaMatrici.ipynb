# %% [markdown]
# # CUDA 10.2.89

# %%
# !wget wget http://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run -O cuda_10.2.deb
# Out:
# --2022-11-22 11:09:42--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2022-11-22 11:09:42--  http://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run [following]
# --2022-11-22 11:09:42--  https://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [1,038 kB]
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# ...

# %%
# !apt-get install cuda-10.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'cuda-10-2' for regex 'cuda-10.2'
# Note, selecting 'libcuda-10.2-1' for regex 'cuda-10.2'
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   cuda-command-line-tools-10-2 cuda-compiler-10-2 cuda-cudart-10-2
#   cuda-cudart-dev-10-2 cuda-cufft-10-2 cuda-cufft-dev-10-2 cuda-cuobjdump-10-2
#   cuda-cupti-10-2 cuda-cupti-dev-10-2 cuda-curand-10-2 cuda-curand-dev-10-2
#   cuda-cusolver-10-2 cuda-cusolver-dev-10-2 cuda-cusparse-10-2
#   cuda-cusparse-dev-10-2 cuda-demo-suite-10-2 cuda-documentation-10-2
#   cuda-driver-dev-10-2 cuda-gdb-10-2 cuda-libraries-10-2
#   cuda-libraries-dev-10-2 cuda-license-10-2 cuda-memcheck-10-2
#   cuda-misc-headers-10-2 cuda-npp-10-2 cuda-npp-dev-10-2 cuda-nsight-10-2
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd '/content/gdrive/My Drive/Colab Notebooks/Esercitazioni/Esercitazione 5'
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Esercitazioni/Esercitazione 5

# %%
! ls
# Out:
#  a.out				   sommaMatrici
#  Colab_CUDA10_sommaMatrici.ipynb   sommaMatriciQuadrate
# 'Esercitazione 5.pdf'		   sommaMatriciQuadrate.cu

# %%
! nvcc sommaMatriciQuadrate.cu -o sommaMatriciQuadrate

# %%
! ./sommaMatriciQuadrate
# Out:
# ***	 SOMMA DI DUE MATRICI QUADRATE 	***
# Inserisci le dimensioni delle matrici M x M
#
# 8192
# tempo GPU = 3.299808
#
# tempo CPU = 332.407745

# %%
! nvcc sommaMatriciRettangolari.cu -o sommaMatriciRettangolari

# %%
! ./sommaMatriciRettangolari
# Out:
# ***	 SOMMA DI DUE MATRICI RETTANGOLARI 	***
# Inserisci il numero delle righe matrice M x N
# 15232
# Inserisci il numero delle colonne della matrice M x N
# 12437
# tempo GPU = 9.240608
#
# tempo CPU = 908.359375

# %%
# !nvidia-smi
# Out:
# Wed Nov 23 15:13:53 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc -Xptxas -v sommaMatriciQuadrate.cu
# Out:
# ptxas info    : 0 bytes gmem
# ptxas info    : Compiling entry function '_Z15sommaMatriciGPUPfS_S_ii' for 'sm_52'
# ptxas info    : Function properties for _Z15sommaMatriciGPUPfS_S_ii
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 8 registers, 352 bytes cmem[0]

# %%
# !nvprof ./sommaMatriciQuadrate
# Out:
# ***	 SOMMA DI DUE MATRICI QUADRATE 	***
# Inserisci le dimensioni delle matrici M x M
# 5
# ==2486== NVPROF is profiling process 2486, command: ./sommaMatriciQuadrate
# tempo GPU = 0.054720
#
# tempo CPU = 0.002496
# Matrice U
# -2.00	-2.00	2.00	0.00	-2.00
# -1.00	0.00	-2.00	1.00	1.00
# -1.00	2.00	1.00	2.00	0.00
# 1.00	-1.00	0.00	2.00	-1.00
# -2.00	0.00	1.00	0.00	0.00
# Matrice V
# -1.00	-2.00	2.00	2.00	2.00
# -1.00	1.00	1.00	1.00	1.00
# -2.00	0.00	2.00	-1.00	-2.00
# 2.00	-2.00	0.00	-1.00	2.00
# -2.00	0.00	0.00	-1.00	0.00
# Matrice somma risultante
# -3.00	-4.00	4.00	2.00	0.00
# -2.00	1.00	-1.00	2.00	2.00
# -3.00	2.00	3.00	1.00	-2.00
# 3.00	-3.00	0.00	1.00	1.00
# -4.00	0.00	1.00	-1.00	0.00
# ==2486== Profiling application: ./sommaMatriciQuadrate
# ==2486== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   33.77%  3.2640us         2  1.6320us  1.3760us  1.8880us  [CUDA memcpy HtoD]
# ...

# %%
# !nvcc -Xptxas -v sommaMatriciRettangolari.cu
# Out:
# ptxas info    : 0 bytes gmem
# ptxas info    : Compiling entry function '_Z15sommaMatriciGPUPfS_S_i' for 'sm_52'
# ptxas info    : Function properties for _Z15sommaMatriciGPUPfS_S_i
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 8 registers, 348 bytes cmem[0]
